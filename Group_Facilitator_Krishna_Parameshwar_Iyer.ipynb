# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the Dataset 

df1 = pd.read_csv('C:\\Users\\krish\\Downloads\\loan\\loan.csv')

# %%
df1.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
#Information regarding the Data in the Dataset

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
df1.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
df1['addr_state'].isna().sum()
# Out:
# 0

# %%
df1.isna().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
#Check for any duplicate records in the data set 
df1.duplicated(['id']).sum()
# Out:
# 0

# %%
#Dropping the columns which are null . 
df1.drop(df1.iloc[:,53:], inplace = True, axis = 1)

# %%
df1['next_pymnt_d'].isna().sum()
# Out:
# 38577

# %%
df1['next_pymnt_d'].fillna(value= 'Not Mentioned', inplace = True)

# %%
df1[df1['next_pymnt_d'].apply(lambda x : x != 'Not Mentioned')]
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 4      1075358    1311748       3000         3000       3000.00000
# 32     1065420    1299514      10000        10000       9975.00000
# 39     1069346    1304237      12500        12500      12475.00000
# 86     1063958    1297940      14000        14000      13975.00000
# 95     1068575    1303001      15300        15300      15275.00000
# ...        ...        ...        ...          ...              ...
# 15972   725556     920821      10400        10400      10400.00000
# 15981   738420     935790       6000         6000       6000.00000
# 16361   733695     930086      19200        19200      18847.76292
# 16609   728422     924106       9350         9350       9350.00000
# 18215   702171     894029       9000         9000       9000.00000
#
#              term int_rate  installment grade sub_grade  ... recoveries  \
# 4       60 months   12.69%        67.79     B        B5  ...        0.0
# ...

# %%
# Dropping columns which are not essential for the analysis

columns_to_drop = ['url', 'desc', 'zip_code', 'initial_list_status', 'mths_since_last_delinq','mths_since_last_record','next_pymnt_d']
df1.drop(labels=columns_to_drop, inplace = True, axis =1)

# %%
columns_to_drop1 = ["mths_since_last_major_derog","member_id"]
df1.drop(labels=columns_to_drop1, inplace = True, axis =1)

# %%
df1.head()
# Out:
#         id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0  1077501       5000         5000           4975.0   36 months   10.65%
# 1  1077430       2500         2500           2500.0   60 months   15.27%
# 2  1077175       2400         2400           2400.0   36 months   15.96%
# 3  1076863      10000        10000          10000.0   36 months   13.49%
# 4  1075358       3000         3000           3000.0   60 months   12.69%
#
#    installment grade sub_grade                 emp_title  ... total_rec_int  \
# 0       162.87     B        B2                       NaN  ...        863.16
# 1        59.83     C        C4                     Ryder  ...        435.17
# 2        84.33     C        C5                       NaN  ...        605.67
# 3       339.31     C        C1       AIR RESOURCES BOARD  ...       2214.92
# 4        67.79     B        B5  University Medical Group  ...       1037.39
#
# ...

# %%
df1.shape
# Out:
# (39717, 44)

# %%
#Cleaning up the Dataset by removing the <, >, =, + and years from  the emp_length column 

df1['emp_length'] = df1.emp_length.str.extract('(\d+)')

# %%
df1['emp_length']
# Out:
# 0        10
# 1         1
# 2        10
# 3        10
# 4         1
#          ..
# 39712     4
# 39713     3
# 39714     1
# 39715     1
# 39716     1
# Name: emp_length, Length: 39717, dtype: object

# %%
#Cleaning up the Dataset by removing the % symbol from the Interest rate column 

df1['int_rate'] = df1['int_rate'].apply(lambda x : x.replace('%',''))

# %%
df1['int_rate']
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4        12.69
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 39717, dtype: object

# %%
df1.head()
# Out:
#         id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0  1077501       5000         5000           4975.0   36 months    10.65
# 1  1077430       2500         2500           2500.0   60 months    15.27
# 2  1077175       2400         2400           2400.0   36 months    15.96
# 3  1076863      10000        10000          10000.0   36 months    13.49
# 4  1075358       3000         3000           3000.0   60 months    12.69
#
#    installment grade sub_grade                 emp_title  ... total_rec_int  \
# 0       162.87     B        B2                       NaN  ...        863.16
# 1        59.83     C        C4                     Ryder  ...        435.17
# 2        84.33     C        C5                       NaN  ...        605.67
# 3       339.31     C        C1       AIR RESOURCES BOARD  ...       2214.92
# 4        67.79     B        B5  University Medical Group  ...       1037.39
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          39717 non-null  int64
#  1   loan_amnt                   39717 non-null  int64
#  2   funded_amnt                 39717 non-null  int64
#  3   funded_amnt_inv             39717 non-null  float64
#  4   term                        39717 non-null  object
#  5   int_rate                    39717 non-null  object
#  6   installment                 39717 non-null  float64
#  7   grade                       39717 non-null  object
#  8   sub_grade                   39717 non-null  object
#  9   emp_title                   37258 non-null  object
#  10  emp_length                  38642 non-null  object
#  11  home_ownership              39717 non-null  object
#  12  annual_inc                  39717 non-null  float64
# ...

# %%
#Different types of Loan status in the dataset

df1['loan_status'].value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
df2 = df1[df1['loan_status'].apply(lambda x : x == 'Charged Off')]

# %%
#Dataset containing only the Charged off Default Users

df2.head(20)
# Out:
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 1    1077430       2500         2500           2500.0   60 months    15.27
# 8    1071795       5600         5600           5600.0   60 months    21.28
# 9    1071570       5375         5375           5350.0   60 months    12.69
# 12   1064687       9000         9000           9000.0   36 months    13.49
# 14   1069057      10000        10000          10000.0   36 months    10.65
# 21   1039153      21000        21000          21000.0   36 months    12.42
# 24   1069559       6000         6000           6000.0   36 months    11.71
# 26   1069800      15000        15000           8725.0   36 months    14.27
# 27   1069657       5000         5000           5000.0   60 months    16.77
# 46   1069465       5000         5000           5000.0   36 months     8.90
# 50   1069248      15000        15000          15000.0   36 months     9.91
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5627 entries, 1 to 39688
# Data columns (total 44 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          5627 non-null   int64
#  1   loan_amnt                   5627 non-null   int64
#  2   funded_amnt                 5627 non-null   int64
#  3   funded_amnt_inv             5627 non-null   float64
#  4   term                        5627 non-null   object
#  5   int_rate                    5627 non-null   object
#  6   installment                 5627 non-null   float64
#  7   grade                       5627 non-null   object
#  8   sub_grade                   5627 non-null   object
#  9   emp_title                   5143 non-null   object
#  10  emp_length                  5399 non-null   object
#  11  home_ownership              5627 non-null   object
#  12  annual_inc                  5627 non-null   float64
# ...

# %%
df2.issue_d
# Out:
# 1        Dec-11
# 8        Dec-11
# 9        Dec-11
# 12       Dec-11
# 14       Dec-11
#           ...
# 39667    Aug-07
# 39668    Aug-07
# 39669    Aug-07
# 39678    Aug-07
# 39688    Aug-07
# Name: issue_d, Length: 5627, dtype: object

# %%
#Creating two new columns Month and Year from the issue_d column 

issue_datetime = pd.to_datetime(df2.issue_d, format='%b-%y')
df2['year'] = issue_datetime.dt.year
df2['month'] = issue_datetime.dt.month

# %%
df2
# Out:
#             id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 1      1077430       2500         2500           2500.0   60 months    15.27
# 8      1071795       5600         5600           5600.0   60 months    21.28
# 9      1071570       5375         5375           5350.0   60 months    12.69
# 12     1064687       9000         9000           9000.0   36 months    13.49
# 14     1069057      10000        10000          10000.0   36 months    10.65
# ...        ...        ...          ...              ...         ...      ...
# 39667   118823       2500         2500            675.0   36 months    12.80
# 39668   118533       2500         2500            825.0   36 months     9.64
# 39669   118523       6500         6500            225.0   36 months    15.01
# 39678   113179       1000         1000            950.0   36 months    10.59
# 39688   111227      20000        20000           2800.0   36 months    13.43
#
# ...

# %% [markdown]
# ### Univariant Analysis

# %%
#Annual Income of the borrower Boxplot

sns.boxplot(df2.annual_inc)
# Out:
# <AxesSubplot:xlabel='annual_inc'>

# %%
issue_datetime1 = pd.to_datetime(df1.issue_d, format='%b-%y')
df1['year'] = issue_datetime.dt.year
df1['month'] = issue_datetime.dt.month

# %%
df1.head()
# Out:
#         id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0  1077501       5000         5000           4975.0   36 months    10.65
# 1  1077430       2500         2500           2500.0   60 months    15.27
# 2  1077175       2400         2400           2400.0   36 months    15.96
# 3  1076863      10000        10000          10000.0   36 months    13.49
# 4  1075358       3000         3000           3000.0   60 months    12.69
#
#    installment grade sub_grade                 emp_title  ... recoveries  \
# 0       162.87     B        B2                       NaN  ...       0.00
# 1        59.83     C        C4                     Ryder  ...     117.08
# 2        84.33     C        C5                       NaN  ...       0.00
# 3       339.31     C        C1       AIR RESOURCES BOARD  ...       0.00
# 4        67.79     B        B5  University Medical Group  ...       0.00
#
#   collection_recovery_fee  last_pymnt_d last_pymnt_amnt last_credit_pull_d  \
# ...

# %%
df1.loan_amnt.isna().sum()
# Out:
# 0

# %%
#Loan amount boxplot

sns.boxplot(df1.loan_amnt)
# Out:
# <AxesSubplot:xlabel='loan_amnt'>

# %%
df1.funded_amnt.isna().sum()
# Out:
# 0

# %%
#Funded Amount Boxplot

sns.boxplot(df1.funded_amnt)
# Out:
# <AxesSubplot:xlabel='funded_amnt'>

# %%
df1.funded_amnt.describe()
# Out:
# count    39717.000000
# mean     10947.713196
# std       7187.238670
# min        500.000000
# 25%       5400.000000
# 50%       9600.000000
# 75%      15000.000000
# max      35000.000000
# Name: funded_amnt, dtype: float64

# %%
df1.int_rate = df1.int_rate.astype('float64')

# %%
df1.int_rate.describe()
# Out:
# count    39717.000000
# mean        12.021177
# std          3.724825
# min          5.420000
# 25%          9.250000
# 50%         11.860000
# 75%         14.590000
# max         24.590000
# Name: int_rate, dtype: float64

# %%
#Interest Rate Box Plot - Univariant Analysis

sns.boxplot(df1.int_rate)
# Out:
# <AxesSubplot:xlabel='int_rate'>

# %%
df1.loan_status.value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
#Bar Plot for count the borrowers falling under different Loan status - Univariant Analysis

sns.countplot(x="loan_status", data=df1)
#Observation 
#As per the bar plot the number of borrowers in fully paid is the highest and Current is least .
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='count'>

# %%
#Distribution plot of Loan amount taken by the borrowers - Univariant analysis
sns.distplot(df1.loan_amnt,rug = True)
plt.title(label= "Loan Amount Distribution Plot", fontsize = 14)
plt.xlabel("Loan Amount", fontsize = 12)
# Out:
# Text(0.5, 0, 'Loan Amount')

# %%
#Distribution plot of Funded Amount - Univariant Analysis

sns.distplot(df1.funded_amnt ,rug = True)
plt.title(label= "Funded Amount Distribution Plot", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Funded Amount Distribution Plot')

# %%
#Funded Amount Inv distribution plot - Univariant Analysis

sns.distplot(df1.funded_amnt_inv ,rug = True)
plt.title(label= "Funded Amount Inv Distribution Plot", fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Funded Amount Inv Distribution Plot')

# %%
# Creating a new column for Annual Income Amount Range for easy analysis 

df1['Income_amnt_range'] = pd.cut(df1['annual_inc'], [0, 20000, 40000, 60000, 80000,1000000], labels=['0-20000', '20000-40000', '40000-60000', '60000-80000', '80000 +'])

# %%
df1.head()
# Out:
#         id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0  1077501       5000         5000           4975.0   36 months     10.65
# 1  1077430       2500         2500           2500.0   60 months     15.27
# 2  1077175       2400         2400           2400.0   36 months     15.96
# 3  1076863      10000        10000          10000.0   36 months     13.49
# 4  1075358       3000         3000           3000.0   60 months     12.69
#
#    installment grade sub_grade                 emp_title  ...  \
# 0       162.87     B        B2                       NaN  ...
# 1        59.83     C        C4                     Ryder  ...
# 2        84.33     C        C5                       NaN  ...
# 3       339.31     C        C1       AIR RESOURCES BOARD  ...
# 4        67.79     B        B5  University Medical Group  ...
#
#   collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  \
# ...

# %%
# Creating a new column for Loan Amount Range for easy analysis

df1['Loan_amnt_range'] = pd.cut(df1['loan_amnt'], [0, 7000, 14000, 21000, 28000, 35000], labels= ['0-7000','7000-14000', '14000-21000', '21000-28000', '28000+'])

# %%
df1.loan_amnt.value_counts()
# Out:
# 10000    2833
# 12000    2334
# 5000     2051
# 6000     1908
# 15000    1895
#          ...
# 24200       1
# 34675       1
# 16275       1
# 3925        1
# 28750       1
# Name: loan_amnt, Length: 885, dtype: int64

# %%
df1.loan_amnt.max()
# Out:
# 35000

# %%
df1.head()
# Out:
#         id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0  1077501       5000         5000           4975.0   36 months     10.65
# 1  1077430       2500         2500           2500.0   60 months     15.27
# 2  1077175       2400         2400           2400.0   36 months     15.96
# 3  1076863      10000        10000          10000.0   36 months     13.49
# 4  1075358       3000         3000           3000.0   60 months     12.69
#
#    installment grade sub_grade                 emp_title  ... last_pymnt_d  \
# 0       162.87     B        B2                       NaN  ...       Jan-15
# 1        59.83     C        C4                     Ryder  ...       Apr-13
# 2        84.33     C        C5                       NaN  ...       Jun-14
# 3       339.31     C        C1       AIR RESOURCES BOARD  ...       Jan-15
# 4        67.79     B        B5  University Medical Group  ...       May-16
#
# ...

# %%
df1.int_rate.max()
# Out:
# 24.59

# %%
# Creating a new column for Interest Rate Range for easy analysis

df1['int_rate_range'] = pd.cut(df1['int_rate'], [0, 10, 15, 20, 25], labels=['0-10', '10-15', '15-20', '20+'])

# %%
df1.head()
# Out:
#         id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0  1077501       5000         5000           4975.0   36 months     10.65
# 1  1077430       2500         2500           2500.0   60 months     15.27
# 2  1077175       2400         2400           2400.0   36 months     15.96
# 3  1076863      10000        10000          10000.0   36 months     13.49
# 4  1075358       3000         3000           3000.0   60 months     12.69
#
#    installment grade sub_grade                 emp_title  ... last_pymnt_amnt  \
# 0       162.87     B        B2                       NaN  ...          171.62
# 1        59.83     C        C4                     Ryder  ...          119.66
# 2        84.33     C        C5                       NaN  ...          649.91
# 3       339.31     C        C1       AIR RESOURCES BOARD  ...          357.48
# 4        67.79     B        B5  University Medical Group  ...           67.79
#
# ...

# %%
# Plot shows the Purpose of loan and the count of the borrowers taking loan for a purpose as shown in the graph --  Univariant Analysis
sns.countplot(y = 'purpose', data = df1, hue = 'loan_status')
plt.title('Purpose of Loan', fontsize = 14)

#Observtion 
# Maximum loans falls in the debt_consolidation purpose . Charged Off borrowers are more in the debt consolidation purpose
# Out:
# Text(0.5, 1.0, 'Purpose of Loan')

# %%
#Plot for Home Ownership and the count of number of Borrowers falling in the Home Ownership  - Univariant Analysis

sns.countplot(x = 'home_ownership', data = df1, hue = 'loan_status')
plt.title('Home Ownership', fontsize = 14)

#Observation 
# Borrowers having Rented home have taken more loan than Own and Mortage . 
# Charged Off Borrowers are more for Rent Home .
# Out:
# Text(0.5, 1.0, 'Home Ownership')

# %%
#Barplot for Interest rate ranges vs the count of the borrowers following in the Interest rate range 


sns.countplot(y = 'int_rate_range', data = df1, hue = 'loan_status')
plt.title('Interest Rate distribution', fontsize = 14)
plt.ylabel("Interest Rate Range", fontsize = 12)

#Observation 
#Borrowers are the highest for Interest rate 10 - 15 .
# Out:
# Text(0, 0.5, 'Interest Rate Range')

# %% [markdown]
# ## Bivariant Analysis

# %%
#Bivariant Analysis

Income_vs_lone_status = df1.groupby(['Income_amnt_range', 'loan_status']).loan_status.count().unstack().reset_index()

# %%
#Calculating the Charged off Ratio from the total 

Income_vs_lone_status['Total_mem'] = Income_vs_lone_status['Charged Off'] + Income_vs_lone_status['Current'] + Income_vs_lone_status['Fully Paid']
Income_vs_lone_status
Income_vs_lone_status['Charged_off_Ratio'] = Income_vs_lone_status['Charged Off']/Income_vs_lone_status['Total_mem']

# %%
Income_vs_lone_status
# Out:
# loan_status Income_amnt_range  Charged Off  Current  Fully Paid  Total_mem  \
# 0                     0-20000          237        9         943       1189
# 1                 20000-40000         1514      170        7004       8688
# 2                 40000-60000         1729      345        9534      11608
# 3                 60000-80000         1024      240        6597       7861
# 4                     80000 +         1122      376        8859      10357
#
# loan_status  Charged_off_Ratio
# 0                     0.199327
# 1                     0.174263
# 2                     0.148949
# 3                     0.130263
# 4                     0.108333

# %%
#Plot for Annual Income vs Charged off Ratio 

sns.barplot(x= 'Charged_off_Ratio', y = 'Income_amnt_range', data = Income_vs_lone_status)
plt.title('Annual Income Amount vs Charged off Ratio', fontsize = 14)
plt.xlabel("Charged off Ratio", fontsize = 12)
plt.ylabel("Annual Income Amount Range", fontsize = 12)

#Observation 
#Those for whome the Annual Income range fall between 0-20000 fall more under charged off . 
# Borrowers with low annual income generally are Charged off
# Out:
# Text(0, 0.5, 'Annual Income Amount Range')

# %%
loan_amnt_vs_lone_status = df1.groupby(['Loan_amnt_range', 'loan_status']).loan_status.count().unstack().reset_index()
loan_amnt_vs_lone_status['Total_mem'] = loan_amnt_vs_lone_status['Charged Off'] + loan_amnt_vs_lone_status['Current'] + loan_amnt_vs_lone_status['Fully Paid']
loan_amnt_vs_lone_status
loan_amnt_vs_lone_status['Charged_off_Ratio'] = loan_amnt_vs_lone_status['Charged Off']/loan_amnt_vs_lone_status['Total_mem']

# %%
loan_amnt_vs_lone_status
# Out:
# loan_status Loan_amnt_range  Charged Off  Current  Fully Paid  Total_mem  \
# 0                    0-7000         1887      161       12420      14468
# 1                7000-14000         1786      315       11512      13613
# 2               14000-21000         1155      347        5886       7388
# 3               21000-28000          538      176        2252       2966
# 4                    28000+          261      141         880       1282
#
# loan_status  Charged_off_Ratio
# 0                     0.130426
# 1                     0.131198
# 2                     0.156335
# 3                     0.181389
# 4                     0.203588

# %%
#Plot for Loan Amount vs Charged off Ratio 

sns.barplot(y= 'Charged_off_Ratio', x = 'Loan_amnt_range', data = loan_amnt_vs_lone_status)
plt.title('Loan Amount vs Charged off Ratio', fontsize = 14)
plt.xlabel("Loan Amount Range", fontsize = 12)

#Observation
# Chargedoff Ratio is high for the Borrowers taken loan amount more than 28000
# Out:
# Text(0.5, 0, 'Loan Amount Range')

# %%
int_rate_vs_lone_status = df1.groupby(['int_rate_range', 'loan_status']).loan_status.count().unstack().reset_index()
int_rate_vs_lone_status['Total_mem'] = int_rate_vs_lone_status['Charged Off'] + int_rate_vs_lone_status['Current'] + int_rate_vs_lone_status['Fully Paid']
int_rate_vs_lone_status
int_rate_vs_lone_status['Charged_off_Ratio'] = int_rate_vs_lone_status['Charged Off']/int_rate_vs_lone_status['Total_mem']

# %%
int_rate_vs_lone_status
# Out:
# loan_status int_rate_range  Charged Off  Current  Fully Paid  Total_mem  \
# 0                     0-10          830       77       11486      12393
# 1                    10-15         2707      529       15558      18794
# 2                    15-20         1794      432        5432       7658
# 3                      20+          296      102         474        872
#
# loan_status  Charged_off_Ratio
# 0                     0.066973
# 1                     0.144035
# 2                     0.234265
# 3                     0.339450

# %%
#Bar plot for Interest Rate Range vs the Charged off Ratio

sns.barplot(y= 'Charged_off_Ratio', x = 'int_rate_range', data = int_rate_vs_lone_status)
plt.title('Interest Rate vs Charged off Ratio', fontsize = 14)
plt.xlabel("Interest Rate Range", fontsize = 12)

#Observation
# interest rate less than 10% has very less chances of charged off. Intrest rates are starting from minimin 5 %.
# interest rate more than 10% has good chnaces of charged off as compared to other category intrest rates.
# Charged off proportion is increasing with higher intrest rates.
# Out:
# Text(0.5, 0, 'Interest Rate Range')

# %%
home_ownership_vs_lone_status = df1.groupby(['home_ownership', 'loan_status']).loan_status.count().unstack().reset_index()
home_ownership_vs_lone_status['Total_mem'] = home_ownership_vs_lone_status['Charged Off'] + home_ownership_vs_lone_status['Current'] + home_ownership_vs_lone_status['Fully Paid']
home_ownership_vs_lone_status
home_ownership_vs_lone_status['Charged_off_Ratio'] =home_ownership_vs_lone_status['Charged Off']/home_ownership_vs_lone_status['Total_mem']

# %%
home_ownership_vs_lone_status
# Out:
# loan_status home_ownership  Charged Off  Current  Fully Paid  Total_mem  \
# 0                 MORTGAGE       2327.0    638.0     14694.0    17659.0
# 1                     NONE          NaN      NaN         3.0        NaN
# 2                    OTHER         18.0      NaN        80.0        NaN
# 3                      OWN        443.0     83.0      2532.0     3058.0
# 4                     RENT       2839.0    419.0     15641.0    18899.0
#
# loan_status  Charged_off_Ratio
# 0                     0.131774
# 1                          NaN
# 2                          NaN
# 3                     0.144866
# 4                     0.150220

# %%
#Dropping NONE and OTHER home_ownership as it has NaN for most of the columns 

home_ownership_vs_lone_status.drop([1,2], axis = 0, inplace = True)

# %%
home_ownership_vs_lone_status
# Out:
# loan_status home_ownership  Charged Off  Current  Fully Paid  Total_mem  \
# 0                 MORTGAGE       2327.0    638.0     14694.0    17659.0
# 3                      OWN        443.0     83.0      2532.0     3058.0
# 4                     RENT       2839.0    419.0     15641.0    18899.0
#
# loan_status  Charged_off_Ratio
# 0                     0.131774
# 3                     0.144866
# 4                     0.150220

# %%
#Bar Plot for Home Ownership vs the Charged off Ratio 

sns.barplot(y= 'Charged_off_Ratio', x = 'home_ownership', data = home_ownership_vs_lone_status)
plt.title('Home Ownership vs Charged off Ratio', fontsize = 14)
plt.xlabel("Home Ownership", fontsize = 12)

#Observation
#Charged off Proportion is more for borrowers living the in the rented House than own and Mortgage
# Out:
# Text(0.5, 0, 'Home Ownership')

# %%
purpose_vs_lone_status = df1.groupby(['purpose', 'loan_status']).loan_status.count().unstack().reset_index()
purpose_vs_lone_status['Total_mem'] = purpose_vs_lone_status['Charged Off'] + purpose_vs_lone_status['Current'] + purpose_vs_lone_status['Fully Paid']
purpose_vs_lone_status
purpose_vs_lone_status['Charged_off_Ratio'] =purpose_vs_lone_status['Charged Off']/purpose_vs_lone_status['Total_mem']

# %%
purpose_vs_lone_status
# Out:
# loan_status             purpose  Charged Off  Current  Fully Paid  Total_mem  \
# 0                           car        160.0     50.0      1339.0     1549.0
# 1                   credit_card        542.0    103.0      4485.0     5130.0
# 2            debt_consolidation       2767.0    586.0     15288.0    18641.0
# 3                   educational         56.0      NaN       269.0        NaN
# 4              home_improvement        347.0    101.0      2528.0     2976.0
# 5                         house         59.0     14.0       308.0      381.0
# 6                major_purchase        222.0     37.0      1928.0     2187.0
# 7                       medical        106.0     12.0       575.0      693.0
# 8                        moving         92.0      7.0       484.0      583.0
# 9                         other        633.0    128.0      3232.0     3993.0
# 10             renewable_energy         19.0      1.0        83.0      103.0
# ...

# %%
#Bar Plot for Purpose of Loan vs Charged off proportion 

sns.barplot(x = 'Charged_off_Ratio', y = 'purpose', data = purpose_vs_lone_status)
plt.title('Purpose of Loan vs Charged off Ratio', fontsize = 14)
plt.ylabel("Purpose of Loan", fontsize = 12)

#Observation

#Charged Off proportion is more for the purpose of loan as small buisness
#Charged off proportion is less for purposes like wedding , car purchase, major-purchases.
# Out:
# Text(0, 0.5, 'Purpose of Loan')

# %%
address_vs_lone_status = df1.groupby(['addr_state', 'loan_status']).loan_status.count().unstack().reset_index()
address_vs_lone_status['Total_mem'] = address_vs_lone_status['Charged Off'] + address_vs_lone_status['Current'] + address_vs_lone_status['Fully Paid']
address_vs_lone_status
address_vs_lone_status['Charged_off_Ratio'] =address_vs_lone_status['Charged Off']/address_vs_lone_status['Total_mem']

# %%
address_vs_lone_status
# Out:
# loan_status addr_state  Charged Off  Current  Fully Paid  Total_mem  \
# 0                   AK         15.0      2.0        63.0       80.0
# 1                   AL         54.0     17.0       381.0      452.0
# 2                   AR         27.0     10.0       208.0      245.0
# 3                   AZ        123.0     30.0       726.0      879.0
# 4                   CA       1125.0    150.0      5824.0     7099.0
# 5                   CO         98.0     26.0       668.0      792.0
# 6                   CT         94.0     25.0       632.0      751.0
# 7                   DC         15.0      3.0       196.0      214.0
# 8                   DE         12.0      1.0       101.0      114.0
# 9                   FL        504.0     85.0      2277.0     2866.0
# 10                  GA        215.0     39.0      1144.0     1398.0
# 11                  HI         28.0      8.0       138.0      174.0
# 12                  IA          NaN      NaN         5.0        NaN
# ...

# %%
#Bar Plot for Address states vs Charged off proportion 

plt.subplots(figsize=(14, 8))
sns.barplot(y = 'Charged_off_Ratio', x = 'addr_state', data = address_vs_lone_status)
plt.title('Address state vs Charged off Ratio', fontsize = 14)
plt.xlabel("Address States", fontsize = 12)

#Observation
# states NE has very high chances of charged off but number of applications are too low to make any decisions.
# NV,CA and FL states shows good number of charged offs in good number of applications.
# Out:
# Text(0.5, 0, 'Address States')

# %%
verification_vs_lone_status = df1.groupby(['verification_status', 'loan_status']).loan_status.count().unstack().reset_index()
verification_vs_lone_status['Total_mem'] = verification_vs_lone_status['Charged Off'] + verification_vs_lone_status['Current'] + verification_vs_lone_status['Fully Paid']
verification_vs_lone_status
verification_vs_lone_status['Charged_off_Ratio'] =verification_vs_lone_status['Charged Off']/verification_vs_lone_status['Total_mem']

# %%
verification_vs_lone_status
# Out:
# loan_status verification_status  Charged Off  Current  Fully Paid  Total_mem  \
# 0                  Not Verified         2142      227       14552      16921
# 1               Source Verified         1434      310        8243       9987
# 2                      Verified         2051      603       10155      12809
#
# loan_status  Charged_off_Ratio
# 0                     0.126588
# 1                     0.143587
# 2                     0.160122

# %%
#Bar Plot for Verification Status vs Charged off proportion 

sns.barplot(y = 'Charged_off_Ratio', x = 'verification_status', data = verification_vs_lone_status)
plt.title('Verification status vs Charged off Ratio', fontsize = 14)

#Observation
# There is not much difference in charged off proportion.
# This variable doesn't provide any insights for charged off.
# Out:
# Text(0.5, 1.0, 'Verification status vs Charged off Ratio')

# %%
plt.subplots(figsize=(16, 8))
sns.boxplot(y = 'purpose', x = 'loan_amnt', data = df1)
plt.title("Box Plot for Loan Amount and Purpose of Loan", fontsize = 14)
plt.xlabel("Loan Amount", fontsize = 12)
plt.ylabel("Purpose of Loan", fontsize = 12)

#Observation 
#75th quantile and 50th quantile of the Loan amount is maximum for small buisness purpose
# Out:
# Text(0, 0.5, 'Purpose of Loan')

# %%
plt.subplots(figsize=(14, 8))
sns.boxplot(y = 'purpose', x = 'int_rate', data = df1)
plt.title("Box Plot for Interest Rate and Purpose of Loan", fontsize = 14)
plt.xlabel("Interest Rate", fontsize = 12)
plt.ylabel("Purpose of Loan", fontsize = 12)

#Observation
#Interest Rate quantile is more for small buisness purpose
# Out:
# Text(0, 0.5, 'Purpose of Loan')

# %%
sns.barplot(x = 'grade', y = 'annual_inc',data = df1, hue = 'loan_status', estimator=np.mean)
plt.title("Annual Income vs Grade", fontsize = 14)
plt.xlabel("Grade", fontsize = 12)
plt.ylabel("Annual Income", fontsize = 12)


# Observations:
# From this we can conclude that the ones getting 'charged off' have lower annual incomes than the ones 
# who'paid fully' for each and every grade (i.e. at same interest range)
# Out:
# Text(0, 0.5, 'Annual Income')
